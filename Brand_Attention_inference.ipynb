# %% [markdown]
# #Installation

# %%
# !git clone https://github.com/Arhosseini77/Brand_Attention
# %cd Brand_Attention

# %% [markdown]
# ## Install Requirements

# %%
# !pip install -r requirements.txt

# %% [markdown]
# ## Download Weights

# %%
# !mkdir weights
# %cd weights
# !gdown 1gGP4X_lwyd8TlxKeaYfj10mSmDPqrAeT  # Logo-Detection-Yolov8
# !gdown 1fARIELdC2sfQfg2sd4eRWQnDF1tFkRiq  # ECT-SAL weights
# %cd ..

# %% [markdown]
# # Brand-Attion Module
# ![Brand_Attention.png](data:image/png;base64,...)

# %% [markdown]
# ## Brand logo detection

# %%
# !python main_detection_yolov8.py --model="weights/Logo_Detection_Yolov8.pt" --image="test_images/test.jpg" --save-result

# %% [markdown]
# ## Saliency map prediction
#
# ![ECT_SAL_Schematic.png](data:image/png;base64,...)

# %%
# !python main_saliency_prediction.py --img_path "test_images/test.jpg" --weight_path "weights/ECT_SAL.pth" --tmap "test_images/test_tmap.jpg" --output_path "results/"

# %% [markdown]
# ## Brand Attention Tool

# %%
# !python main_brand_attention.py --img_path "test_images/test.jpg" --tmap "test_images/test_tmap.jpg"
